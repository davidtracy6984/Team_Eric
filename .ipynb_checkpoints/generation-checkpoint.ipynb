# %%
import pandas as pd

# %%
df = pd.read_csv("annual_generation_state-DOS.csv").sort_values("Pkey")
df.head(40)
# Out:
#        Pkey  Year State                                    TypeOfProducer  \
# 11002     1  1990    AK                     Total Electric Power Industry
# 23141     2  1990    AK                     Total Electric Power Industry
# 19514     3  1990    AK                     Total Electric Power Industry
# 12856     4  1990    AK                     Total Electric Power Industry
# 23313     5  1990    AK                     Total Electric Power Industry
# 48769     6  1990    AK                     Total Electric Power Industry
# 30490     7  1990    AK                     Total Electric Power Industry
# 11807     8  1990    AK           Electric Generators, Electric Utilities
# 26171     9  1990    AK           Electric Generators, Electric Utilities
# 19515    10  1990    AK           Electric Generators, Electric Utilities
# 13788    11  1990    AK           Electric Generators, Electric Utilities
# 25752    12  1990    AK           Electric Generators, Electric Utilities
# ...
