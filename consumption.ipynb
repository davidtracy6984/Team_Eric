# %%
import pandas as pd

# %%
df = pd.read_csv("annual_consumption_state_dos.csv")
df.head()
# Out:
#    Pkey  Year State                           TypeOfProducer  \
# 0     1  1990    AK            Total Electric Power Industry
# 1     2  1990    AK            Total Electric Power Industry
# 2     3  1990    AK            Total Electric Power Industry
# 3     4  1990    AK  Electric Generators  Electric Utilities
# 4     5  1990    AK  Electric Generators  Electric Utilities
#
#           EnergySource  UseOfElectricity
# 0    Coal  Short Tons             404871
# 1  Petroleum  Barrels             961837
# 2    Natural Gas  Mcf           42764948
# 3    Coal  Short Tons             290182
# 4  Petroleum  Barrels             657706

# %%
df2 = df[df['TypeOfProducer'] == "Total Electric Power Industry"]
df2.head()
# Out:
#     Pkey  Year State                 TypeOfProducer         EnergySource  \
# 0      1  1990    AK  Total Electric Power Industry    Coal  Short Tons
# 1      2  1990    AK  Total Electric Power Industry  Petroleum  Barrels
# 2      3  1990    AK  Total Electric Power Industry    Natural Gas  Mcf
# 10    11  1990    AL  Total Electric Power Industry    Coal  Short Tons
# 11    12  1990    AL  Total Electric Power Industry  Petroleum  Barrels
#
#     UseOfElectricity
# 0             404871
# 1             961837
# 2           42764948
# 10          22242353
# 11            249875

# %%
df3 = df2[(df2['State'] == 'US-TOTAL') | (df2['State'] == 'US-Total')]
df3.head()
# Out:
#       Pkey  Year     State                 TypeOfProducer  \
# 614    615  1990  US-TOTAL  Total Electric Power Industry
# 615    616  1990  US-TOTAL  Total Electric Power Industry
# 616    617  1990  US-TOTAL  Total Electric Power Industry
# 617    618  1990  US-TOTAL  Total Electric Power Industry
# 1271  1272  1991  US-TOTAL  Total Electric Power Industry
#
#                    EnergySource  UseOfElectricity
# 614           Coal  Short Tons          792457493
# 615         Petroleum  Barrels          218800036
# 616           Natural Gas  Mcf         3691562664
# 617   Other Gases  Billion BTU             111750
# 1271          Coal  Short Tons          793665533

# %%
#df['TypeOfProducer'].unique()
#df['EnergySource'].unique()
df['State'].unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY', 'US-TOTAL', 'US-Total'],
#       dtype=object)

# %%
df_coal = df3[df3['EnergySource'] == 'Coal  Short Tons ']
df_oil = df3[df3['EnergySource'] == 'Petroleum  Barrels ']
df_lng = df3[df3['EnergySource'] == 'Natural Gas  Mcf ']
df_og = df3[(df3['EnergySource'] == 'Other Gases  Billion BTU ') | (df3['EnergySource'] == 'Other Gases  Billion Btu ')]
#df_og2 = df3[df3['EnergySource'] == 'Other Gases  Billion Btu ']
df_geo = df3[df3['EnergySource'] == 'Geothermal  Billion Btu ']

# %%
df_og
# Out:
#         Pkey  Year     State                 TypeOfProducer  \
# 617      618  1990  US-TOTAL  Total Electric Power Industry
# 1274    1275  1991  US-TOTAL  Total Electric Power Industry
# 1942    1943  1992  US-TOTAL  Total Electric Power Industry
# 2623    2624  1993  US-TOTAL  Total Electric Power Industry
# 3316    3317  1994  US-TOTAL  Total Electric Power Industry
# 4014    4015  1995  US-TOTAL  Total Electric Power Industry
# 4722    4723  1996  US-TOTAL  Total Electric Power Industry
# 5440    5441  1997  US-TOTAL  Total Electric Power Industry
# 6165    6166  1998  US-TOTAL  Total Electric Power Industry
# 6896    6897  1999  US-TOTAL  Total Electric Power Industry
# 7647    7648  2000  US-TOTAL  Total Electric Power Industry
# 8406    8407  2001  US-TOTAL  Total Electric Power Industry
# 9188    9189  2002  US-TOTAL  Total Electric Power Industry
# 9966    9967  2003  US-TOTAL  Total Electric Power Industry
# 10748  10749  2004  US-TOTAL  Total Electric Power Industry
# ...

# %%
len(df)*2
# Out:
# 43442
